# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import csv

# %% [markdown]
# ## Define

# %%
#TRAIN_DATA_FILES = ['cross','dead_end', 'left', 'right', 'straight', 'threeway_left'. 'threeway_center', 'threeway_right']
TRAIN_DATA_FILE = "new_straight"
NUM_CLASSES = len(TRAIN_DATA_FILE)
MAX_RANGE = 240

REPLACE_NAN = 0.0

MARGIN = 1.5
RESOLUTION = 20.0 #(cm)
WIDTH = HEIGHT = int(3000 * 2 / RESOLUTION + 2)

# %% [markdown]
# ## 学習データ読み込み用関数

# %%
def split_data():
#    files = os.listdir('/content/drive/My Drive/Colab Notebooks/data')
    X = []

    for i in range(NUM_CLASSES):
        try:
          # header = 列名
            file_name = "/content/drive/My Drive/Colab Notebooks/data2/" + TRAIN_DATA_FILE + ".csv"
            data_set = pd.read_csv(file_name, header=None)
        except pd.io.common.EmptyDataError:
            print("ERROR: {} is empty".format(file_name))

#    X = pd.concat(data_set)
    # replace Nan with 'REPLACE_NAN'
    X = data_set.fillna(REPLACE_NAN)

    return data_set, X.values

# %% [markdown]
# ## file close

# %%
def file_close():
  read_file.close()
  output_file.close()

# %% [markdown]
# ## Plot

# %%
read_file = open('/content/drive/My Drive/Colab Notebooks/data2/' + TRAIN_DATA_FILE + '.csv', 'a')
output_file = open('/content/drive/My Drive/Colab Notebooks/data2/old_' + TRAIN_DATA_FILE + '.csv', 'a')

dir_output_file = '/content/drive/My Drive/Colab Notebooks/data2/old_' + TRAIN_DATA_FILE + '.csv'

# %%
X, X_val = split_data()

# %%
X.shape
# Out:
# (5954, 721)

# %%
X2 = X[0:5941]

# %%
pd.DataFrame(X2).to_csv(dir_output_file, mode='a', header=False, index=False)

# %%
file_close()
