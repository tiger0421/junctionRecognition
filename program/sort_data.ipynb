# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
import csv

# %%
INPUT_DATA_FILE = "4-4"
output_data_file = "new_" + INPUT_DATA_FILE

input_dir = "/content/drive/My Drive/Colab Notebooks/data2/" + INPUT_DATA_FILE + ".csv"
output_dir = "/content/drive/My Drive/Colab Notebooks/data2/" + output_data_file + ".csv"

# %% [markdown]
# ### データ読み込み

# %%
try:
# header = 列名
  data_set = pd.read_csv(input_dir, index_col=None)
except pd.io.common.EmptyDataError:
  print("ERROR: {} is empty".format(input_dir))

# %% [markdown]
# ### データ抽出 & 保存

# %%
f = open(output_dir, 'a')

# %%
sorted_data = data_set.loc[:, "field.ranges0":"field.ranges720"]
pd.DataFrame(sorted_data).to_csv(output_dir, mode='a', header=False, index=False)

# %%
f.close()
